# %% [markdown]
# <a href="https://colab.research.google.com/github/ericyoc/adversarial-defense-cnn-poc/blob/main/cyber_domain_tools_ref_poc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
from prettytable import PrettyTable

def create_table1(data):
    table = PrettyTable()
    table.field_names = ["Cyber Analysis Domain", "Cyber Tool", "Tool Description"]
    table.align["Cyber Analysis Domain"] = "l"
    table.align["Cyber Tool"] = "l"
    table.align["Tool Description"] = "l"

    for row in data:
        table.add_row(row[:3])

    return table

def create_table2(data):
    table = PrettyTable()
    table.field_names = ["Cyber Analysis Domain", "Cyber Tool", "Usage", "File Type"]
    table.align["Cyber Analysis Domain"] = "l"
    table.align["Cyber Tool"] = "l"
    table.align["Usage"] = "l"
    table.align["File Type"] = "l"

    for row in data:
        table.add_row([row[0], row[1], row[3], row[6]])

    return table

def create_table3(data):
    table = PrettyTable()
    table.field_names = ["Cyber Analysis Domain", "Cyber Tool", "Reason for Cyber Analysis to Use It"]
    table.align["Cyber Analysis Domain"] = "l"
    table.align["Cyber Tool"] = "l"
    table.align["Reason for Cyber Analysis to Use It"] = "l"

    for row in data:
        table.add_row([row[0], row[1], row[4]])

    return table

def create_table4(data):
    table = PrettyTable()
    table.field_names = ["Cyber Analysis Domain", "Cyber Tool", "Expected Outcome"]
    table.align["Cyber Analysis Domain"] = "l"
    table.align["Cyber Tool"] = "l"
    table.align["Expected Outcome"] = "l"

    for row in data:
        table.add_row([row[0], row[1], row[5]])

    return table

def save_to_csv(data, filename, headers):
    with open(filename, 'w', newline='') as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(headers)
        writer.writerows(data)

def main():
    data = [
        ["Reverse Engineering (Firmware)", "BinWalk", "Firmware analysis tool\nTool Type: Firmware Analysis\nDownload: https://github.com/ReFirmLabs/binwalk", "Extracts firmware components", "Identify firmware structure and contents", "Understand firmware components and architecture", "Firmware"],
        ["Reverse Engineering (Firmware)", "QEMU", "Emulation and virtualization tool\nTool Type: Emulation and Virtualization\nDownload: https://www.qemu.org/download/", "Emulates firmware environment", "Analyze firmware behavior in a controlled environment", "Observe firmware execution and interactions", "Firmware"],
        ["Reverse Engineering (Firmware)", "FAT-ng", "Firmware analysis toolkit\nTool Type: Firmware Analysis\nDownload: https://github.com/attify/firmware-analysis-toolkit", "Automates firmware analysis tasks", "Streamline firmware analysis process", "Identify vulnerabilities and extract firmware components", "Firmware"],
        ["Reverse Engineering (Firmware)", "Firmwalker", "Firmware analysis script\nTool Type: Firmware Analysis\nDownload: https://github.com/craigz28/firmwalker", "Searches for interesting files and patterns", "Identify potential security issues and sensitive information", "Discover firmware vulnerabilities and misconfigurations", "Firmware"],
        ["Malware Analysis", "PE Studio", "PE file analysis tool\nTool Type: PE File Analysis\nDownload: https://www.winitor.com/", "Analyzes PE file structure and properties", "Understand PE file characteristics and potential malicious behavior", "Identify suspicious PE file attributes and indicators", "PE"],
        ["Malware Analysis", "QEMU", "Emulation and virtualization tool\nTool Type: Emulation and Virtualization\nDownload: https://www.qemu.org/download/", "Emulates malware environment", "Analyze malware behavior in a controlled environment", "Observe malware execution and interactions", "PE, ELF, Mach-O"],
        ["Malware Analysis", "Cuckoo Sandbox", "Automated malware analysis sandbox\nTool Type: Malware Analysis Sandbox\nDownload: https://cuckoosandbox.org/", "Analyzes malware behavior in a controlled environment", "Understand malware functionality and interactions", "Generate detailed malware analysis reports", "PE, ELF, Mach-O"],
        ["Malware Analysis", "Process Monitor (ProcMon)", "System monitoring tool\nTool Type: System Monitoring\nDownload: https://docs.microsoft.com/en-us/sysinternals/downloads/procmon", "Monitors system activities and process behavior", "Identify malware's interactions with the system", "Trace malware's actions and system modifications", "PE"],
        ["Malware Analysis", "OllyDbg", "Debugger for Windows binaries\nTool Type: Debugger\nDownload: http://www.ollydbg.de/", "Debugs and analyzes malware at the assembly level", "Understand malware's low-level behavior and code execution", "Identify malware's functionality and evasion techniques", "PE"],
        ["Malware Analysis", "Fakenet-ng", "Network simulation tool\nTool Type: Network Simulation\nDownload: https://github.com/fireeye/flare-fakenet-ng", "Simulates network services and Internet connectivity", "Analyze malware's network communications and interactions", "Identify malware's command and control (C2) servers and network indicators", "N/A"],
        ["Malware Analysis", "PEiD", "Packing detection tool\nTool Type: Packing Detection\nDownload: https://www.aldeid.com/wiki/PEiD", "Detects common packers, cryptors, and compilers", "Identify packed or obfuscated malware", "Determine the packing or obfuscation method used", "PE"],
        ["Malware Analysis", "Detect It Easy (DIE)", "Packing detection tool\nTool Type: Packing Detection\nDownload: https://github.com/horsicq/Detect-It-Easy", "Detects packers, cryptors, and compilers", "Identify packed or obfuscated malware", "Determine the packing or obfuscation method used", "PE, ELF, Mach-O"],
        ["Malware Analysis", "oletools", "Malicious document analysis tool\nTool Type: Maldoc Analysis\nDownload: https://github.com/decalage2/oletools", "Analyzes and extracts information from Microsoft Office files", "Identify malicious macros, scripts, and shellcode in Office documents", "Detect and extract suspicious content from Office files", "Office Documents"],
        ["Malware Analysis", "olevba", "VBA macro analysis tool\nTool Type: Maldoc Analysis\nDownload: https://github.com/decalage2/oletools/wiki/olevba", "Extracts and analyzes VBA macros from Office documents", "Identify malicious VBA macros in Office documents", "Deobfuscate and understand the functionality of VBA macros", "Office Documents"],
        ["Malware Analysis", "XLMMacroDeobfuscator", "Excel 4.0 macro deobfuscator\nTool Type: Maldoc Analysis\nDownload: https://github.com/DissectMalware/XLMMacroDeobfuscator", "Deobfuscates and analyzes Excel 4.0 macros", "Identify malicious Excel 4.0 macros", "Understand the functionality of obfuscated Excel 4.0 macros", "Excel Documents"],
        ["Malware Analysis", "Yara", "Pattern matching tool\nTool Type: Malware Analysis\nDownload: https://github.com/VirusTotal/yara", "Defines and matches patterns in malware samples", "Identify and classify malware based on specific patterns", "Detect malware variants and families", "PE, ELF, Mach-O"],
        ["Malware Analysis", "signsrch", "Signature-based malware detection tool\nTool Type: Malware Analysis\nDownload: https://github.com/sherpya/signsrch", "Searches for specific byte sequences in files", "Identify malware based on known signatures", "Detect specific malware variants or families", "PE, ELF, Mach-O"],
        ["Software Exploitation Analysis", "OllyDbg", "Debugger for Windows binaries\nTool Type: Debugger\nDownload: http://www.ollydbg.de/", "Debugs and analyzes software at the assembly level", "Understand software's low-level behavior and code execution", "Identify vulnerabilities and exploit development opportunities", "PE"],
        ["Software Exploitation Analysis", "x64dbg", "Debugger for Windows binaries\nTool Type: Debugger\nDownload: https://x64dbg.com/", "Debugs and analyzes software at the assembly level", "Understand software's low-level behavior and code execution", "Identify vulnerabilities and exploit development opportunities", "PE"],
        ["Software Exploitation Analysis", "WinDbg", "Debugger for Windows binaries\nTool Type: Debugger\nDownload: https://docs.microsoft.com/en-us/windows-hardware/drivers/debugger/debugger-download-tools", "Debugs and analyzes software at the assembly level", "Understand software's low-level behavior and code execution", "Identify vulnerabilities and exploit development opportunities", "PE"],
        ["Software Exploitation Analysis", "GDB (GNU Debugger)", "Debugger for Unix-based systems\nTool Type: Debugger\nDownload: https://www.gnu.org/software/gdb/", "Debugs and analyzes software at the assembly level", "Understand software's low-level behavior and code execution", "Identify vulnerabilities and exploit development opportunities", "ELF"],
        ["Software Exploitation Analysis", "Metasploit", "Exploitation framework\nTool Type: Exploitation Framework\nDownload: https://www.metasploit.com/", "Develops and executes exploits against vulnerable systems", "Test software vulnerabilities and exploit them", "Assess the impact and feasibility of exploits", "N/A"],
        ["Common Analysis Tools", "Data Duplicator (DD command)", "Data duplication and imaging tool\nTool Type: Data Duplication\nBuilt-in tool in Unix-based systems", "Creates forensic disk images", "Preserve and analyze disk data", "Create a forensic copy of the disk for analysis", "N/A"],
        ["Common Analysis Tools", "File command", "File type identification tool\nTool Type: File Type Identification\nBuilt-in tool in Unix-based systems", "Identifies file types based on file signatures", "Determine the file type and format", "Identify file types for further analysis", "N/A"],
        ["Common Analysis Tools", "Strings command", "String extraction tool\nTool Type: String Extraction\nBuilt-in tool in Unix-based systems", "Extracts printable strings from files", "Identify interesting strings and potential indicators", "Extract relevant strings for analysis", "N/A"],
        ["Common Analysis Tools", "IDA Pro", "Disassembler and debugger\nTool Type: Disassembler and Decompiler\nDownload: https://www.hex-rays.com/products/ida/", "Disassembles and analyzes binary code", "Understand binary code structure and functionality", "Identify interesting code segments and vulnerabilities", "PE, ELF, Mach-O"],
        ["Common Analysis Tools", "Ghidra", "Reverse engineering tool\nTool Type: Disassembler and Decompiler\nDownload: https://ghidra-sre.org/", "Disassembles and analyzes binary code", "Understand binary code structure and functionality", "Identify interesting code segments and vulnerabilities", "PE, ELF, Mach-O"],
        ["Common Analysis Tools", "Wireshark", "Network protocol analyzer\nTool Type: Network Analysis\nDownload: https://www.wireshark.org/", "Captures and analyzes network traffic", "Understand network communication and protocols", "Identify suspicious network activities and indicators", "PCAP"],
        ["Common Analysis Tools", "Burp Suite", "Web application security testing tool\nTool Type: Web Application Security\nDownload: https://portswigger.net/burp", "Analyzes and tests web application security", "Identify vulnerabilities and misconfigurations in web applications", "Perform manual and automated security testing of web applications", "N/A"],
        ["Online Analysis Tools", "Joe Sandbox", "Automated malware analysis platform\nTool Type: Malware Analysis\nAccess: https://www.joesecurity.org/", "Analyzes malware behavior in a cloud environment", "Understand malware functionality and interactions", "Generate detailed malware analysis reports", "PE, ELF, Mach-O"],
        ["Online Analysis Tools", "Any.Run", "Interactive malware analysis platform\nTool Type: Malware Analysis\nAccess: https://any.run/", "Analyzes malware behavior in a web-based environment", "Understand malware functionality and interactions", "Interact with malware execution and observe behavior", "PE, ELF, Mach-O"],
        ["Online Analysis Tools", "Hybrid Analysis", "Malware analysis and threat intelligence platform\nTool Type: Malware Analysis\nAccess: https://www.hybrid-analysis.com/", "Analyzes malware and provides threat intelligence", "Understand malware characteristics and associated threats", "Obtain detailed malware analysis reports and threat intelligence", "PE, ELF, Mach-O"],
        ["Online Analysis Tools", "URLhaus", "Malicious URL database\nTool Type: Threat Intelligence\nAccess: https://urlhaus.abuse.ch/", "Provides information on malicious URLs", "Identify and investigate malicious URLs", "Obtain threat intelligence on malicious URLs", "N/A"],
        ["Online Analysis Tools", "CyberChef", "Web-based data transformation tool\nTool Type: Data Transformation\nAccess: https://gchq.github.io/CyberChef/", "Performs various data transformations and analyses", "Manipulate and analyze data", "Decode, encrypt, compress, and perform various data operations", "N/A"],
        ["Online Analysis Tools", "VirusTotal", "Online malware analysis and threat intelligence platform\nTool Type: Malware Analysis\nAccess: https://www.virustotal.com/", "Analyzes malware samples and provides threat intelligence", "Understand malware characteristics and associated threats", "Obtain malware analysis reports and threat intelligence", "PE, ELF, Mach-O"],
        ["Analysis Platforms", "Radare2", "Reverse engineering framework\nTool Type: Reverse Engineering\nDownload: https://rada.re/n/radare2.html", "Disassembles, analyzes, and debugs binary code", "Understand binary code structure and functionality", "Identify interesting code segments and vulnerabilities", "PE, ELF, Mach-O"],
        ["Analysis Platforms", "FLARE VM", "Reverse engineering and malware analysis framework\nTool Type: Malware Analysis\nDownload: https://github.com/fireeye/flare-vm", "Provides tools and scripts for malware analysis", "Automate malware analysis tasks", "Identify malware characteristics and behavior", "PE, ELF, Mach-O"],
        ["Analysis Platforms", "Kali Linux", "Linux distribution for security testing and analysis\nTool Type: Security Testing\nDownload: https://www.kali.org/", "Provides a wide range of security tools", "Perform various security testing and analysis tasks", "Conduct comprehensive security assessments and analyses", "N/A"],
        ["Analysis Platforms", "REMnux", "Linux distribution for reverse engineering and malware analysis\nTool Type: Malware Analysis\nDownload: https://remnux.org/", "Provides tools and scripts for malware analysis", "Analyze malware behavior and characteristics", "Perform in-depth malware analysis and reverse engineering", "PE, ELF, Mach-O"],
        ["Analysis Platforms", "Capa", "Malware analysis framework\nTool Type: Malware Analysis\nDownload: https://github.com/fireeye/capa", "Detects capabilities and behaviors in executable files", "Identify malware capabilities and behaviors", "Understand the functionality and intent of malware", "PE, ELF, Mach-O"]
]

    table1 = create_table1(data)
    print("Table 1:")
    print(table1)
    table1_data = [row[:3] for row in data]
    save_to_csv(table1_data, "domain_tool_description.csv", ["Cyber Analysis Domain", "Cyber Tool", "Tool Description"])

    table2 = create_table2(data)
    print("\nTable 2:")
    print(table2)
    table2_data = [[row[0], row[1], row[3], row[6]] for row in data]
    save_to_csv(table2_data, "domain_tool_usage_filetype.csv", ["Cyber Analysis Domain", "Cyber Tool", "Usage", "File Type"])

    table3 = create_table3(data)
    print("\nTable 3:")
    print(table3)
    table3_data = [[row[0], row[1], row[4]] for row in data]
    save_to_csv(table3_data, "domain_tool_reason.csv", ["Cyber Analysis Domain", "Cyber Tool", "Reason for Cyber Analysis to Use It"])

    table4 = create_table4(data)
    print("\nTable 4:")
    print(table4)
    table4_data = [[row[0], row[1], row[5]] for row in data]
    save_to_csv(table4_data, "domain_tool_expected_outcome.csv", ["Cyber Analysis Domain", "Cyber Tool", "Expected Outcome"])

    print("\nData saved to separate CSV files with meaningful names.")

if __name__ == "__main__":
    main()
# Out:
# Table 1:
# +--------------------------------+------------------------------+------------------------------------------------------------------------------------------------------+
# | Cyber Analysis Domain          | Cyber Tool                   | Tool Description                                                                                     |
# +--------------------------------+------------------------------+------------------------------------------------------------------------------------------------------+
# | Reverse Engineering (Firmware) | BinWalk                      | Firmware analysis tool                                                                               |
# |                                |                              | Tool Type: Firmware Analysis                                                                         |
# ...
